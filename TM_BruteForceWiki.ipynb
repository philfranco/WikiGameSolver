# %%
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize

# %%
def getText(start_article, end_article):
    url = 'https://en.wikipedia.org/w/api.php'
    params = {
                'action': 'parse',
                'page': start_article,
                'format': 'json',
                'prop':'text',
                'redirects':''
            }
 
    response = requests.get(url, params=params)
    data = response.json()
 
    raw_html = data['parse']['text']['*']
    soup = BeautifulSoup(raw_html,'html.parser')
    soup.find_all('p')
    text = ''
 
    for p in soup.find_all('p'):
        text += p.text
    
    print(len(word_tokenize(text)))
    print('Number of words: ', len(text))

    return text

# %%
def getLinks(start_article): 
    url = 'https://en.wikipedia.org/w/api.php'
 
    params = {
        'action': 'query',
        'format': 'json',
        'titles': start_article,
        'prop': 'links',
        'pllimit': 'max',
        'redirects':''
    }
 
    response = requests.get(url=url, params=params)
    data = response.json()
 
    pages = data['query']['pages']
    page = 1
    page_titles = []
 
    for key, val in pages.items():
        for link in val['links']:
            page_titles.append(link['title'])
 
    while 'continue' in data:
        plcontinue = data['continue']['plcontinue']
        params['plcontinue'] = plcontinue
 
        response = requests.get(url=url, params=params)
        data = response.json()
        pages = data['query']['pages']
     
        page += 1
     
        for key, val in pages.items():
            for link in val['links']:
                page_titles.append(link['title'])
 
    #page_titles[:3]
    print(len(page_titles[:]))
    return page_titles

# %%
#Now we can do, put a start and end article or word. We would then try to loop through the links,
#Then go down the links and search the page for the end article. 
#We'll also have to log each link we used to move on.
start_article = "Star World Championship"
end_article = "America's Cup"
getText(start_article, end_article)
getLinks(start_article)
# Out:
# 324
# Number of words:  1791
# 602
# ['12 Metre World Championship',
#  '1923 Star World Championship',
#  '1923 Star World Championships',
#  '1924 Star World Championship',
#  '1924 Star World Championships',
#  '1925 Star World Championship',
#  '1925 Star World Championships',
#  '1926 Star World Championship',
#  '1926 Star World Championships',
#  '1927 Star World Championship',
#  '1927 Star World Championships',
#  '1928 Star World Championship',
#  '1928 Star World Championships',
#  '1929 Star World Championship',
#  '1929 Star World Championships',
#  '1930 Star World Championship',
#  '1930 Star World Championships',
#  '1931 Star World Championship',
#  '1931 Star World Championships',
#  '1932 Star World Championship',
#  '1932 Star World Championships',
#  '1933 Star World Championship',
#  '1933 Star World Championships',
#  '1934 Star World Championship',
#  '1934 Star World Championships',
#  '1935 Star World Championship',
#  '1935 Star World Championships',
#  '1936 Star World Championship',
#  '1936 Star World Championships',
#  '1937 Star World Championship',
#  '1937 Star World Championships',
#  '1938 Star World Championship',
#  '1938 Star World Championships',
#  '1939 Star World Championship',
#  '1939 Star World Championships',
#  '1940 Star World Championship',
#  '1940 Star World Championships',
#  '1941 Star World Championship',
#  '1941 Star World Championships',
#  '1942 Star World Championship',
#  '1942 Star World Championships',
#  '1943 Star World Championship',
#  '1943 Star World Championships',
#  '1944 Star World Championship',
#  '1944 Star World Championships',
#  '1945 Star World Championship',
#  '1945 Star World Championships',
#  '1946 Star World Championship',
#  '1946 Star World Championships',
#  '1947 Star World Championship',
#  '1947 Star World Championships',
#  '1948 Star World Championship',
#  '1948 Star World Championships',
#  '1949 Star World Championship',
#  '1949 Star World Championships',
#  '194 Star World Championships',
#  '1950 Star World Championship',
#  '1950 Star World Championships',
#  '1951 Star World Championship',
#  '1951 Star World Championships',
#  '1952 Star World Championship',
#  '1952 Star World Championships',
#  '1953 Star World Championship',
#  '1953 Star World Championships',
#  '1954 Star World Championship',
#  '1954 Star World Championships',
#  '1955 Star World Championship',
#  '1955 Star World Championships',
#  '1956 Star World Championship',
#  '1956 Star World Championships',
#  '1957 Star World Championships',
#  '1958 Star World Championships',
#  '1959 Star World Championships',
#  '1960 Star World Championships',
#  '1961 Star World Championships',
#  '1962 Star World Championships',
#  '1963 Star World Championships',
#  '1964 Star World Championships',
#  '1965 Star World Championships',
#  '1966 Star World Championships',
#  '1967 Star World Championships',
#  '1968 Summer Olympics',
#  '1969 Star World Championships',
#  '1970 Star World Championships',
#  '1971 Star World Championships',
#  '1972 Star World Championships',
#  '1973 Star World Championships',
#  '1974 Star World Championships',
#  '1975 Star World Championships',
#  '1976 Star World Championships',
#  '1977 Star World Championships',
#  '1978 Star World Championships',
#  '1979 Star World Championships',
#  '1980 Star World Championships',
#  '1981 Star World Championships',
#  '1982 Star World Championships',
#  '1983 Star World Championships',
#  '1984 Star World Championships',
#  '1985 Star World Championships',
#  '1986 Star World Championships',
#  '1987 Star World Championships',
#  '1988 Star World Championships',
#  '1989 Star World Championships',
#  '1990 Star World Championship',
#  '1990 Star World Championships',
#  '1991 Star World Championship',
#  '1991 Star World Championships',
#  '1992 Star World Championship',
#  '1992 Star World Championships',
#  '1993 Star World Championship',
#  '1993 Star World Championships',
#  '1994 Star World Championships',
#  '1995 Star World Championships',
#  '1996 Star World Championships',
#  '1997 Star World Championships',
#  '1998 Star World Championships',
#  '1999 Star World Championships',
#  '2000 Star World Championships',
#  '2001 Star World Championships',
#  '2002 Star World Championship',
#  '2002 Star World Championships',
#  '2003 ISAF Sailing World Championships',
#  '2003 ISAF Sailing World Championships – Star',
#  '2004 Star World Championship',
#  '2004 Star World Championships',
#  '2005 Star World Championships',
#  '2006 Star World Championships',
#  '2007 ISAF Sailing World Championships',
#  '2007 ISAF Sailing World Championships – Star',
#  '2008 Star World Championship',
#  '2008 Star World Championships',
#  '2009 Star World Championships',
#  '2010 Star World Championship',
#  '2010 Star World Championships',
#  '2011 ISAF Sailing World Championships',
#  '2011 ISAF Sailing World Championships – Star',
#  '2011 Star World Championships',
#  '2012 Star World Championships',
#  '2013 Star World Championships',
#  '2014 ISAF Sailing World Championships',
#  '2014 Star World Championship',
#  '2014 Star World Championships',
#  '2015 Star World Championships',
#  '2016 Star World Championship',
#  '2016 Star World Championships',
#  '2017 Star World Championship',
#  '2017 Star World Championships',
#  '2018 Sailing World Championships',
#  '2018 Star World Championship',
#  '2018 Star World Championships',
#  '2019 Star World Championship',
#  '2019 Star World Championships',
#  '2020 Star World Championship',
#  '2021 Star World Championship',
#  '2022 Star World Championship',
#  '2022 Star World Championships',
#  '420 World Championships',
#  '470 World Championships',
#  '49er & 49er FX World Championships',
#  '5.5 Metre World Championship',
#  '505 (dinghy)',
#  '6 Metre World Cup',
#  'Adrian Iselin',
#  'Adrian Iselin (sailor)',
#  'Agostino Straulino',
#  'Alan Adler (sailor)',
#  'Albert Debarge',
#  'Alberto Garcia Tunon',
#  'Albino Fravezzi',
#  'Alexander Hagen',
#  'Alfio Peraboni',
#  'Anders Ekström',
#  'Andreas Josenhans',
#  'Andrew Campbell (sailor)',
#  'Andrew Menkart',
#  'Andrew Simpson (sailor)',
#  'Annapolis',
#  'Antonio Gorostegui',
#  'Antonio Gorostegui Ceballos',
#  'Argentina',
#  'Arne Akerson',
#  'Arthur Deacon',
#  'Arthur Knapp',
#  'Arthur Knapp, Jr.',
#  'Asa L. Colson',
#  'Augie Diaz',
#  'Australia',
#  'Barton Beek',
#  'Bayside Yacht Club',
#  'Ben Comstock',
#  'Benny Andersen (sailor)',
#  'Bermuda',
#  'Bill Buchan, Jr.',
#  'Bill Hackel',
#  'Bill Wright (sailor)',
#  'Blair Fletcher',
#  'Bobby Lohse',
#  'Boston',
#  'Brazil',
#  'Brian Fatih',
#  'Brian Ledbetter',
#  'Bruce MacDonald (sailor)',
#  'Bruno Prada',
#  'Buddy Melges',
#  'Buenos Aires',
#  'Cadet World Championship',
#  'Canada',
#  'Cannes',
#  'Capri',
#  'Caracas',
#  'Carl Buchan',
#  'Carl F. Sutter',
#  'Carl Williams (sailor)',
#  'Carlos De Cardenas Culmell',
#  'Carlos De Cardenas Pla',
#  'Carlos de Cárdenas',
#  'Carlos de Cárdenas, Jr.',
#  'Cascais',
#  'Central Long Island Sound',
#  'Charles Lewsadder',
#  'Charles Turtle',
#  'Chesapeake Bay',
#  'Chicago',
#  'Chick Rollins',
#  'Chris Rasmusten',
#  'Christian Blankenburg',
#  'Christian Finnsgård',
#  'Clair L. Farrand',
#  'Class40',
#  'Claudio Biekarch',
#  'Claus Olesen',
#  'Cleveland',
#  'Colin Beashel',
#  'Colin Ratsey',
#  'Copenhagen',
#  'Craig Monk',
#  'Craig Thomas (sailor)',
#  'Cuba',
#  'Cádiz',
#  'Dan Hubers',
#  'David Giles (sailor)',
#  "David O'Brien (sailor)",
#  'David Shaw (sailor)',
#  'Denmark',
#  'Dennis Conner',
#  'Diego Negri',
#  'Ding Schoonmaker',
#  'Dominik Zycki',
#  'Dominik Życki',
#  'Donald Bever',
#  'Donald K. Edler',
#  'Donald Trask',
#  'Douglas Knight (sailor)',
#  'Dragon World Championship',
#  'Duarte Manuel Bello',
#  'Durward Knowles',
#  'E. W. Etchells',
#  'ESailing World Championship',
#  'Earl Lasher',
#  'Eastern Hemisphere Championship',
#  'Ed Adams',
#  'Ed Bennett (sailor)',
#  'Ed Willis',
#  'Edgar Beyn',
#  'Edward Fink',
#  'Edwin Thorne (sailor)',
#  'Eivind Melleby',
#  'Enrico Chieffi',
#  'Enrico De Maria',
#  'Eric Doyle (sailor)',
#  'Eric Jespersen',
#  'Europe World Championships',
#  'Farr 30 (yacht)',
#  'Farr 40',
#  'Farr 45',
#  'Fernando Pinto Coelho Bello',
#  'Finn Gold Cup',
#  'Flavio Marazzi',
#  'Flying Dutchman World Championship',
#  'France',
#  'Francis Dolan',
#  'Frank Hogg (sailor)',
#  'Franz Wehofsich',
#  'Fredrik Lööf',
#  'Frithjof Kleen',
#  'Fritz Girr',
#  'G. H. C. Phillips',
#  'G. K. C. Phillips',
#  'Gaeta',
#  'Garrett Horder',
#  'Gary Comer',
#  'Gary Mull',
#  'Gavin Brady',
#  'George Fleitz',
#  'George Iverson',
#  'George Szabo III',
#  'Gerald Driscoll',
#  'Gerald Ford (sailor)',
#  'Germany',
#  'Gibson Island (Maryland)',
#  'Gilbert Gray',
#  'Giorgio Gorla',
#  'Giuseppe Milone',
#  'Gordon Cowie',
#  'Gordon Holcombe',
#  'Graham Johnson (sailor)',
#  'Great South Bay',
#  'Guilherme Hamelmann',
#  'Göran Tell',
#  'Hal Haenel',
#  'Hamish Pepper',
#  'Hans-Christian Nehammer',
#  'Hans-Joachim Weise',
#  'Hans Wallén',
#  'Harry Gale Nye, Jr.',
#  'Harry Nye, Jr.',
#  'Harry Nye Jr',
#  'Harry Rugeroni',
#  'Harry Wylie',
#  'Havana',
#  'Henry Boening',
#  'Herbert Williams (sailor)',
#  'Hilary Smart',
#  'Hook Beardslee',
#  'Hugo Schreiner',
#  'Hyères',
#  'IQFoil World Championships',
#  'ISAF Offshore Team Racing World Championship',
#  'ISAF Open Match Racing World Championship',
#  'ISAF Sailing World Championships',
#  'ISAF Team Racing World Championship',
#  'Iain Percy',
#  'Ingvar Hansson',
#  'International A Class (radiosailing)',
#  'International Marblehead (radiosailing)',
#  'International One Metre (radiosailing)',
#  'International Sailing Federation',
#  'International Star Class Yacht Racing Association',
#  'International Ten Rater (radiosailing)',
#  'International class',
#  'Italy',
#  'Jack Robinson (sailor)',
#  'James Allsopp',
#  'James B. Hill (sailor)',
#  'James Cowie (sailor)',
#  'James Kavle',
#  'James Reynolds (sailor)',
#  'Jerry Ford (sailor)',
#  'Joachim Griese',
#  'Joe Duplin',
#  'Joe Londrigan',
#  'Joerg Bruder',
#  'Johann Spitzauer',
#  'John Albrechtson',
#  'John Bennett (sailor)',
#  'John Gerald Driscoll III',
#  'John MacCausland',
#  'John McKeague (sailor)',
#  'John von Schwarz',
#  'Jorge Zarif',
#  'Jorge de Cárdenas',
#  'Jose Luis Doreste Blanco',
#  'Joseph Duplin',
#  'Joseph Watkins (sailor)',
#  'Joshua Revkin',
#  'José Doreste',
#  'João Miguel Tito',
#  'Kai Bjorn',
#  'Kai Falkenthal',
#  'Karsten Meyer (sailor)',
#  'Kasper Harsberg',
#  'Ken Keefe',
#  'Kent Edler',
#  'Kiel',
#  'Kobus Vandenberg',
#  'Lake Michigan',
#  'Laredo, Cantabria',
#  'Lars Grael',
#  'Laser 4.7 World Championships',
#  'Laser World Championship',
#  'Lawdens Johnson',
#  'Leif Carlsson',
#  'List of World Championships medalists in sailing (centreboard classes)',
#  'List of World Championships medalists in sailing (juniors and youth classes)',
#  'List of World Championships medalists in sailing (keelboat classes)',
#  'List of World Championships medalists in sailing (multihull classes)',
#  'List of World Championships medalists in sailing (para classes)',
#  'List of World Championships medalists in sailing (radio sailing classes)',
#  'List of World Championships medalists in sailing (windsurfer classes)',
#  'List of World Championships medalists in sailing (yacht classes)',
#  'Livio Sangulin',
#  'Lockwood Pirie',
#  'Long Beach',
#  'Long Island Sound',
#  'Los Angeles',
#  'Lowell North',
#  'Luigi Viale',
#  'Lynn Williams (sailor)',
#  'Magnus Liljedahl',
#  'Malcesine',
#  'Malin Burnham',
#  'Manhasset Bay Yacht Club',
#  'Marblehead, Massachusetts',
#  'Marcelo Ferreira',
#  'Marcelo Fuchs',
#  'Marina del Rey',
#  'Mario Salani',
#  'Mark Mansfield',
#  'Mark Mendelblatt',
#  'Mark Reynolds (sailor)',
#  'Mark Yorsto',
#  'Mark Yorston',
#  'Marstrand',
#  'Mary Etchelles',
#  'Mateusz Kusznierewicz',
#  'Mats Johansson (sailor)',
#  'Medemblik',
#  "Men's Laser Radial World Championship",
#  'Miami',
#  'Michael Guhin',
#  'Michael Hestbæk',
#  'Michael Marcel',
#  'Michael Marcour',
#  'Mike Dorgan (sailor)',
#  'Milton Wegeforth',
#  'Mogens Just Mikkelsen',
#  'Mort Carlile',
#  'Myron Lehman',
#  'Myron Lehmann',
#  'Nacra 17 World Championship',
#  'Naples',
#  'Narragansett Bay',
#  'Nassau, Bahamas',
#  'Nazi Germany',
#  'Nelson Falcão',
#  'Netherlands',
#  'New Orleans',
#  'New Zealand',
#  'Newell Weed',
#  'Newport Beach',
#  'Nicolo Rode',
#  'Nicolò Rode',
#  'Norway',
#  'Optimist World Championship',
#  'Oscar Dalvit',
#  'Owen Torrey',
#  'Oxford, Maryland',
#  'Para World Sailing Championships',
#  'Pascal Rambeau',
#  'Paul Bert Elvstrøm',
#  'Paul Cayard',
#  'Paul Elvstrom',
#  'Paul Elvstrøm',
#  'Paul Smart (sailor)',
#  'Paul Sradnick',
#  'Pelle Petterson',
#  'Pelle Pettersson',
#  'Perry Roehm',
#  'Perth',
#  'Peter Barrett (sailor)',
#  'Peter Bromby',
#  'Peter Hansohm',
#  'Peter Wilhauser',
#  'Peter Wright (sailor)',
#  'Phil Trinter',
#  'Poland',
#  'Porto Cervo',
#  'Portoroz',
#  'Portugal',
#  'Poul Mik-Meyer',
#  'Prentice Edrington',
#  'Puget Sound',
#  'Punta Ala',
#  'R. M. Allan III',
#  'Regatta',
#  'Reinhard Schmidt',
#  'Republic of Ireland',
#  'Richard Edwards (sailor)',
#  'Richard Stearns (sailor)',
#  'Rick Peters (sailor)',
#  'Rio de Janeiro',
#  'Robert Levin (sailor)',
#  'Robert Lippincott',
#  'Robert Nelson (sailor)',
#  'Robert Rodgers (sailor)',
#  'Robert Scheidt',
#  'Robert Stanjek',
#  'Robert White (sailor)',
#  'Roberto Benamati',
#  'Roberto Mottola',
#  'Roberto Sinibaldi',
#  'Rochester, New York',
#  'Rodrigo Meirelles',
#  'Ron Anderson (sailor)',
#  'Ronald Seifert',
#  'Ross MacDonald',
#  'Sailing (sport)',
#  'Sailing World Championships',
#  'Samuel Gonçalves',
#  'San Diego',
#  'San Francisco',
#  'San Isidro, Buenos Aires',
#  'Sergio Lambertenghi',
#  'Sloane Farrington',
#  'Slovenia',
#  'Snipe World Championships',
#  'Soling World Championship',
#  'Spain',
#  'Stan Ogilvy',
#  'Stanley Fahlstrom',
#  'Stanley Fahlström',
#  'Star (keelboat)',
#  'Star (sailboat)',
#  'Star European Championship',
#  'Star North American Championship',
#  'Star South American Championship',
#  'Stefan Hemlin',
#  'Steve Erickson (sailor)',
#  'Steve Mitchell (sailor)',
#  'Steven Bakker',
#  'Steven Erickson',
#  'Steven Richard Erickson',
#  'Stig Wennerström (sailor)',
#  'Sture Christiansen',
#  'Sune Carlsson',
#  'Swan 45 (yacht)',
#  'Sweden',
#  'Switzerland',
#  'Sydney 40',
#  'TP 52 (yacht)',
#  'Tempest (keelboat)',
#  'The Bahamas',
#  'Thomas Dudinsky',
#  'Thorsten Helmert',
#  'Tito Nordio',
#  'Todd Cozzens',
#  'Tom Blackaller',
#  'Tom Olsen',
#  'Tom Skahill',
#  'Tonci Stipanovic',
#  'Torben Grael',
#  'Tornado World Championship',
#  'Troense',
#  'Tudor Bilic',
#  'Ulf Schröder',
#  'Ulrich Seeberger',
#  'United Kingdom',
#  'United States',
#  'Uwe von Below',
#  'Varberg',
#  'Venezuela',
#  'Vicente Brun',
#  'Vilamoura',
#  'Vince Brun',
#  'Vincent Hoesch',
#  'Vincent Hösch',
#  'W.L. Inslee',
#  'Walt Hubbard, Jr.',
#  'Walter Krug',
#  'Walter von Hütschler',
#  'Walther Von Hütschler',
#  'Washington Yacht Club',
#  'Werner Fritz',
#  'West Germany',
#  'Western Hemisphere Championship',
#  'Whitney Stueck',
#  'Wilhelm Kuhweide',
#  'William Carl Buchan',
#  'William Earl Buchan',
#  'William Gentzlinger',
#  'William Gidley',
#  'William Glenn Waterhouse',
#  'William Inslee',
#  'William Kreysler',
#  'William McHugh (sailor)',
#  'William Munster',
#  'William P. Ficker',
#  'William Pickford (sailor)',
#  'William Severence',
#  'Windsurfing World Championships',
#  "Women's Laser Radial World Championship",
#  "Women's Match Racing World Championship",
#  'Woodbridge Metcalf',
#  'World Sailing',
#  'World championships in sailing',
#  'X-35 (yacht)',
#  'X-41 (yacht)',
#  'X-99 (yacht)',
#  'Xavier Rohart',
#  'Yannick Adde',
#  'Yngling (keelboat)',
#  'Youth Sailing World Championships',
#  'Álvaro de Cárdenas',
#  'Template:Footer World Champions Star',
#  'Template:StarWorlds',
#  'Template:Star World Championship medallists',
#  'Template:World championships in sailing',
#  'Template talk:Footer World Champions Star',
#  'Template talk:StarWorlds',
#  'Template talk:Star World Championship medallists',
#  'Template talk:World championships in sailing',
#  'Category:Use dmy dates from June 2022']
